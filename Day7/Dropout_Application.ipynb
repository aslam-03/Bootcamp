# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer,Input, Dense, Dropout
from tensorflow.keras.optimizers import RMSprop,Adam,Adadelta
from tensorflow.keras.utils import to_categorical
import cv2
import os
from sklearn.utils import shuffle

# %%
dataset_path = "C:\\Users\\ASLAM\\Desktop\\Bootcamp\\Day6\\digits"  

images = []
labels = []

for digit in range(10):
    folder_path = os.path.join("C:\\Users\\ASLAM\\Desktop\\Bootcamp\\Day6\\digits", str(digit))
    
    for img_name in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img_name)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        
        if img is None:
            print(f"Skipping corrupt image: {img_path}")
            continue
        
        img = cv2.resize(img, (28, 28))  
        img = img / 255.0  
        images.append(img)
        labels.append(digit)


X = np.array(images).reshape(-1, 28*28)  
y = to_categorical(labels, num_classes=10)  

print(X.shape)  
print(y.shape)
# Out:
# (10160, 784)
# (10160, 10)

# %%
X, y = shuffle(X, y, random_state=42)

# %%
model = Sequential([
    Dense(50, activation='relu', input_shape=(784,)),
    Dropout(0.001),
    Dense(10,activation='softmax'),
])

# %%
model.compile(optimizer=Adam(learning_rate=0.0001),loss='categorical_crossentropy',metrics=['accuracy'])
history_adam=model.fit(X,y,epochs=20,validation_split=0.2)
# Out:
# Epoch 1/20
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2622 - loss: 2.1821 - val_accuracy: 0.7151 - val_loss: 1.4242
# Epoch 2/20
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7430 - loss: 1.3034 - val_accuracy: 0.8494 - val_loss: 0.9466
# Epoch 3/20
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8486 - loss: 0.8980 - val_accuracy: 0.8799 - val_loss: 0.6798
# Epoch 4/20
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8704 - loss: 0.6717 - val_accuracy: 0.8976 - val_loss: 0.5367
# Epoch 5/20
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8915 - loss: 0.5337 - val_accuracy: 0.9124 - val_loss: 0.4453
# Epoch 6/20
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9019 - loss: 0.4640 - val_accuracy: 0.9178 - val_loss: 0.3847
# Epoch 7/20
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9153 - loss: 0.4018 - val_accuracy: 0.9193 - val_loss: 0.3459
# Epoch 8/20
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9183 - loss: 0.3664 - val_accuracy: 0.9213 - val_loss: 0.3205
# Epoch 9/20
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9252 - loss: 0.3296 - val_accuracy: 0.9296 - val_loss: 0.2893
# Epoch 10/20
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9245 - loss: 0.3107 - val_accuracy: 0.9296 - val_loss: 0.2782
# Epoch 11/20
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9292 - loss: 0.2953 - val_accuracy: 0.9336 - val_loss: 0.2571
# Epoch 12/20
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9340 - loss: 0.2666 - val_accuracy: 0.9395 - val_loss: 0.2405
# Epoch 13/20
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9317 - loss: 0.2536 - val_accuracy: 0.9409 - val_loss: 0.2313
# Epoch 14/20
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9361 - loss: 0.2475 - val_accuracy: 0.9375 - val_loss: 0.2229
# Epoch 15/20
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9417 - loss: 0.2284 - val_accuracy: 0.9429 - val_loss: 0.2101
# Epoch 16/20
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9471 - loss: 0.2131 - val_accuracy: 0.9405 - val_loss: 0.2074
# Epoch 17/20
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9437 - loss: 0.2169 - val_accuracy: 0.9444 - val_loss: 0.1960
# Epoch 18/20
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9474 - loss: 0.1984 - val_accuracy: 0.9429 - val_loss: 0.1913
# Epoch 19/20
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9449 - loss: 0.2088 - val_accuracy: 0.9483 - val_loss: 0.1797
# Epoch 20/20
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9517 - loss: 0.1823 - val_accuracy: 0.9508 - val_loss: 0.1746

# %%
plt.plot(history_adam.history['loss'],label='Training loss')
plt.plot(history_adam.history['val_loss'],label='validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.title('Loss Comparision')
# Out:
# Text(0.5, 1.0, 'Loss Comparision')

# %%
plt.plot(history_adam.history['accuracy'],label='Training accuracy')
plt.plot(history_adam.history['val_accuracy'],label='validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid()
plt.legend()
plt.title('Accuracy Comparison')
# Out:
# Text(0.5, 1.0, 'Accuracy Comparison')
