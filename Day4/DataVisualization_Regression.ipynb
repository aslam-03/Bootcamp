# %%
#TASK 2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.datasets import load_diabetes

data = load_diabetes()
df = pd.DataFrame(data.data, columns=data.feature_names)

X = df[['bmi']]
y = data.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)


model = LinearRegression()
model.fit(X_train, y_train)


y_pred = model.predict(X_test)
r2 = r2_score(y_test, y_pred)

print('Linear Regression R² Score:',r2 )
print("coeffecient:",model.coef_)
print("Intercept:",model.intercept_)

plt.scatter(X_test, y_test, color='blue', label='Actual Data')
plt.plot(X_test, y_pred, color='red', label='Regression Line')

plt.xlabel('BMI')
plt.ylabel('Diabetes Progression')
plt.title('Linear Regression - BMI vs Diabetes')
plt.legend()
plt.show()
# Out:
# Linear Regression R² Score: 0.2824176223694733
# coeffecient: [952.1529647]
# Intercept: 152.98435982643292
